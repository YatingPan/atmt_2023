# %% [markdown]
# <a href="https://colab.research.google.com/github/YatingPan/atmt_2023/blob/main/ATMT_Assignment03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/YatingPan/atmt_2023.git
# Out:
# Cloning into 'atmt_2023'...
# remote: Enumerating objects: 305, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 305 (delta 38), reused 45 (delta 31), pack-reused 202
# Receiving objects: 100% (305/305), 57.12 MiB | 46.53 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
# %cd /content/atmt_2023
# Out:
# /content/atmt_2023

# %%
#!python preprocess.py \
#  --source-lang en \
#  --target-lang fr \
#  --train-prefix data/en-fr/raw/train \
#  --valid-prefix data/en-fr/raw/valid \
#  --test-prefix data/en-fr/raw/test \
#  --dest-fir data/en-fr/preprocessed/

# %% [markdown]
# ## Experiment01: Hyperparameter
#
# Learning rate: 0.0003 -> 0.0001
#
# batch size: 1 -> 16

# %%
# !python train.py \
  --data data/en-fr/prepared \
  --source-lang en \
  --target-lang fr \
  --save-dir assignments/03/Experiment01/checkpoints \
  --lr 0.0001 \
  --batch-size 16 \
  --cuda
# Out:
# INFO: Commencing training!
# INFO: COMMAND: train.py --data data/en-fr/prepared --source-lang en --target-lang fr --save-dir assignments/03/Experiment01/checkpoints --lr 0.0001 --batch-size 16 --cuda
# ...

# %%
# !python translate.py \
  --data data/en-fr/prepared/ \
  --dicts data/en-fr/prepared/ \
  --checkpoint-path assignments/03/Experiment01/checkpoints/checkpoint_best.pt \
  --output assignments/03/Experiment01/translations.txt
# Out:
# [2023-11-04 13:24:20] COMMAND: translate.py --data data/en-fr/prepared/ --dicts data/en-fr/prepared/ --checkpoint-path assignments/03/Experiment01/checkpoints/checkpoint_best.pt --output assignments/03/Experiment01/translations.txt
# ...

# %%
# !bash scripts/postprocess.sh assignments/03/Experiment01/translations.txt assignments/03/Experiment01/translations.p.txt en

# %%
# !pip install sacrebleu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 2.6 MB/s eta 0:00:00
# ...

# %%
# !cat assignments/03/Experiment01/translations.p.txt | sacrebleu data/en-fr/raw/test.fr
# Out:
# {
#  "name": "BLEU",
#  "score": 4.7,
#  "signature": "nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.3.1",
#  "verbose_score": "27.5/6.9/2.5/1.0 (BP = 1.000 ratio = 1.452 hyp_len = 5828 ref_len = 4015)",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.3.1"
# }

# %%
# !git config --global user.email "panyating0322@gmail.com"
# !git config --global user.name "YatingPan"

# %%
# !git add .

# %%
# !git commit -m "Added results of Experiment01"
# Out:
# [main 6bef27a] Added results of Experiment01
#  11 files changed, 1000 insertions(+)
#  create mode 100644 assignments/03/Experiment01/checkpoints/checkpoint_best.pt
#  create mode 100644 assignments/03/Experiment01/checkpoints/checkpoint_last.pt
#  create mode 100644 assignments/03/Experiment01/translations.p.txt
#  create mode 100644 assignments/03/Experiment01/translations.txt

# %%
# !git push https://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@github.com/YatingPan/atmt_2023.git
# Out:
# Enumerating objects: 35, done.
# Counting objects: 100% (35/35), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (24/24), done.
# Writing objects: 100% (24/24), 27.69 MiB | 12.16 MiB/s, done.
# Total 24 (delta 9), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (9/9), completed with 8 local objects.
# To https://github.com/YatingPan/atmt_2023.git
#    e53ff18..6bef27a  main -> main

# %% [markdown]
# ## Experiment 02: BPE
#
# Here created a new preprocess script called "bpe_preprocess.py", in the same directory of the original preprocess.py

# %%
# !pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.5 MB/s eta 0:00:00
# ...

# %%
# !python bpe_preprocess.py \
    --source-lang en \
    --target-lang fr \
    --train-prefix data/en-fr/raw/train \
    --valid-prefix data/en-fr/raw/valid \
    --test-prefix data/en-fr/raw/test \
    --dest-dir data-bin
# Out:
# [2023-11-04 14:13:15] COMMAND: bpe_preprocess.py --source-lang en --target-lang fr --train-prefix data/en-fr/raw/train --valid-prefix data/en-fr/raw/valid --test-prefix data/en-fr/raw/test --dest-dir data-bin
# [2023-11-04 14:13:15] Arguments: {'source_lang': 'en', 'target_lang': 'fr', 'train_prefix': 'data/en-fr/raw/train', 'tiny_train_prefix': None, 'valid_prefix': 'data/en-fr/raw/valid', 'test_prefix': 'data/en-fr/raw/test', 'dest_dir': 'data-bin', 'threshold_src': 2, 'num_words_src': -1, 'threshold_tgt': 2, 'num_words_tgt': -1, 'vocab_src': None, 'vocab_trg': None, 'quiet': False}
# [2023-11-04 14:13:15] COMMAND: bpe_preprocess.py --source-lang en --target-lang fr --train-prefix data/en-fr/raw/train --valid-prefix data/en-fr/raw/valid --test-prefix data/en-fr/raw/test --dest-dir data-bin
# ...

# %%
# !python train.py \
  --data data-bin \
  --source-lang en \
  --target-lang fr \
  --save-dir assignments/03/Experiment02/checkpoints \
  --cuda
# Out:
# INFO: Commencing training!
# INFO: COMMAND: train.py --data data-bin --source-lang en --target-lang fr --save-dir assignments/03/Experiment02/checkpoints --cuda
# ...

# %%
# !python translate.py \
  --data data-bin \
  --dicts data-bin \
  --checkpoint-path assignments/03/Experiment02/checkpoints/checkpoint_best.pt \
  --output assignments/03/Experiment02/translations.txt
# Out:
# [2023-11-04 17:08:59] COMMAND: translate.py --data data-bin --dicts data-bin --checkpoint-path assignments/03/Experiment02/checkpoints/checkpoint_best.pt --output assignments/03/Experiment02/translations.txt
# ...

# %%
# !sed -i 's/\r$//' scripts/bpe_postprocess.sh

# %%
# !bash scripts/bpe_postprocess.sh assignments/03/Experiment02/translations.txt assignments/03/Experiment02/translations.p.txt en

# %%
# !cat assignments/03/Experiment02/translations.p.txt | sacrebleu data/en-fr/raw/test.fr
# Out:
# {
#  "name": "BLEU",
#  "score": 6.5,
#  "signature": "nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.3.1",
#  "verbose_score": "25.1/9.2/4.0/1.9 (BP = 1.000 ratio = 1.900 hyp_len = 7630 ref_len = 4015)",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.3.1"
# }
